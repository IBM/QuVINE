# %%
import sys
import os
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from glob import glob

# %%
PATH='../../results/'
dg = ['hn4', 'ppi_complete', 'hg' ]
res_dict = {}
for f in glob(PATH+'*.csv'):
    for d in dg: 
        if d in f: 
            res_dict[d] = pd.read_csv(f)

cols = []
for k,v in res_dict.items():
    print(k)
    cols.append(set(v.columns))

common_cols = set.union(*cols)
common_cols = list(common_cols)
set(common_cols) - set(res_dict['ppi_complete'].columns)
# Out:
# hn4
# hg
# ppi3
# {'betti_0',
#  'betti_1',
#  'betti_2',
#  'betti_sum',
#  'euler_characteristic',
#  'persistence_entropy_H0',
#  'persistence_entropy_H1',
#  'persistence_entropy_H2'}
